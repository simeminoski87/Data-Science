# %% [markdown]
# # Lab Exercise 1. Scraping Static Websites

# %% [markdown]
# This is the warmup task for the first laboratory exercise. It consists of scraping static Websites with BeautifulSoap.
#
#  It should be completed at home and presented at the laboratory.

# %% [markdown]
# **Total points: 2**

# %% [markdown]
# ### Task Description

# %% [markdown]
# Scrape the information about the products on the following page:
# https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/

# %% [markdown]
# For each product scrape:
#
#
# *   Product title (selector `'.wd-entities-title'`)
# *   Product regular price (selector `'.woocommerce-Price-amount'`)
# *   Product discount price (if available), same selector as regular price
# *   URL to the product page
# *   Add to cart button URL
#
# ***Help: There are multiple product pages, for each page you need to send a separate request***

# %% [markdown]
# Save the results as a DataFrame object

# %% [markdown]
# You can add as many code cells as you need.

# %% [markdown]
# ________________________________________________________________

# %% [markdown]
# ### Requirements

# %% [markdown]
# Import libraries and modules that you are going to use

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user-pc\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\user-pc\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user-pc\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user-pc\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\User-PC\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import datetime
import pandas as pd
import requests as req
import urllib3
from bs4 import BeautifulSoup
from IPython.display import HTML
import warnings

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
warnings.filterwarnings("ignore")

def get_soup(snapshot_url):
    response = req.get(snapshot_url)

    if response.status_code != 200:
        raise Exception("Something went wrong")

    raw_html = response.text
    soup = BeautifulSoup(raw_html, "html.parser")
    return soup

def print_elements(collection):
    for element in collection:
        print(element)
def format_white_space(string:str):
    return " ".join(string.split())

# %% [markdown]
# ### Send HTTP request to the target Website

# %%
snapshot_url = "https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/"
response = req.get(snapshot_url)

# %% [markdown]
# check the response status code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Parse the response content with BeautifulSoap

# %%
try:
    soup = get_soup(snapshot_url)
except Exception as e:
    print(e)
    exit(1)

# %% [markdown]
# ### Extract data from the BeautifulSoap object using any selectors, attribute identifiers, etc.

# %% [markdown]
# * Product title (selector '.wd-entities-title')
# * Product regular price (selector '.woocommerce-Price-amount')
# * Product discount price (if available), same selector as regular price
# * URL to the product page
# * Add to cart button URL

# %%
page_numbers = soup.select(".page-numbers li")
max_pages = int(page_numbers[-2].text)
num_pages = [i for i in range(1, max_pages + 1)]

products_page_url = "https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/"
products = []
for page_number in num_pages:
    fetch_url = products_page_url + str(page_number) + "/"
    try:
        page_soup = get_soup(fetch_url)
    except Exception as e:
        continue

    product_elements = page_soup.select(".product-wrapper")
    for product_element in product_elements:
        title = product_element.select_one(".wd-entities-title").select_one("a").text
        children = list(product_element.select_one(".price").children)

        if len(children) == 1:
            regular_price = children[0].text
            discounted_price = "0 ден"
        else:
            regular_price = product_element.select(".woocommerce-Price-amount")[0].select_one("bdi").text
            discounted_price = product_element.select(".woocommerce-Price-amount")[1].select_one("bdi").text
        regular_price = format_white_space(regular_price)
        discounted_price = format_white_space(discounted_price)

        product_link = product_element.select_one(".product-image-link").get("href")
        query_string = product_element.select_one(".add_to_cart_button").get("href")
        if query_string.startswith("?"):
            add_to_cart_link = fetch_url + query_string
        else:
            add_to_cart_link = None
        product = {"title": title, "price": regular_price, "discounted_price": discounted_price, "link": product_link, "add_to_cart": add_to_cart_link}
        products.append(product)

# %% [markdown]
# Repeat the extraction process for each page of products

# %%
products
# Out:
# [{'title': 'Acer A315-23-A7KD',
#   'price': '17.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-a315-23-a7kd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21494'},
#  {'title': 'Acer A315-23-R5P2',
#   'price': '27.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-a315-23-r5p2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21510'},
#  {'title': 'ACER Aspire 1 A115-22',
#   'price': '18.999 ден',
#   'discounted_price': '15.999 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-1-nx-a7pex-001/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=20826'},
#  {'title': 'Acer Aspire 3 A315-23-R26A',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-3-a315-23-r26a/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21516'},
#  {'title': 'Acer Aspire 3 A315-58-33WK',
#   'price': '24.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/21498/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21498'},
#  {'title': 'Acer Aspire 3 A315-58-33WK',
#   'price': '25.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-3-a315-58-33wk/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21506'},
#  {'title': 'ACER Aspire 5 (A515-56-35KA)',
#   'price': '23.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-56-35ka/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21693'},
#  {'title': 'ACER ASPIRE 5 A515-45',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-45/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21523'},
#  {'title': 'Acer Aspire 5 A515-45-R07Y Silver',
#   'price': '24.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r07y-silver/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21501'},
#  {'title': 'Acer Aspire 5 A515-45-R1FG',
#   'price': '36.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r1fgnx-a7yex-005/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=18324'},
#  {'title': 'Acer Aspire 5 A515-56',
#   'price': '42.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-56-nx-a1eex-001/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=18498'},
#  {'title': 'Acer Aspire 5 A515-56-3456 Silver',
#   'price': '23.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-5-a515-56-3456-silver/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21690'},
#  {'title': 'ACER Aspire 7 (A715-41G-R24S), Black',
#   'price': '42.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-7-a715-41g-r24s-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21695'},
#  {'title': 'Acer Aspire 7 A715-42G-R16C',
#   'price': '54.490 ден',
#   'discounted_price': '48.490 ден',
#   'link': 'https://clevershop.mk/product/acer-aspire-7-a715-42g-r16c-nh-qe5ex-003/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=18506'},
#  {'title': 'ACER ED270RPBIIPX 27′ LED VA FHD',
#   'price': '14.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-ed270rpbiipx-27-led-va-fhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21728'},
#  {'title': 'ACER ED273BBMIIX 27′ LED VA FHD',
#   'price': '11.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-ed273bbmiix-27-led-va-fhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21734'},
#  {'title': 'ACER ED323QURABIDPX 32” LED VA WQHD',
#   'price': '20.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-ed323qurabidpx-32-led-va-wqhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21737'},
#  {'title': 'ACER K272HLEbid 27” LED VA FHD',
#   'price': '9.690 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/21743/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21743'},
#  {'title': 'ACER LED 19.5”, V206HQLAB, Wide',
#   'price': '5.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-led-19-5-v206hqlab-wide/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21750'},
#  {'title': 'ACER LED, 21.5” V226HQLBbi',
#   'price': '6.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-led-21-5-v226hqlbbi/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21755'},
#  {'title': 'ACER Nitro 5 (AN515-57-53A7)',
#   'price': '51.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-an515-57-53a7/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21706'},
#  {'title': 'Acer Nitro 5 (AN515-57-53AE)',
#   'price': '47.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-an515-57/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21716'},
#  {'title': 'Acer Nitro 5 (AN515-57-76C9)',
#   'price': '60.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-an515-57-2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21718'},
#  {'title': 'Acer Nitro 5 Gaming AN515-45',
#   'price': '71.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/1/?add-to-cart=21406'},
#  {'title': 'Acer Nitro 5 Gaming AN515-45',
#   'price': '66.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45-2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21410'},
#  {'title': 'Acer Nitro 5 Gaming AN517-41',
#   'price': '73.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-gaming-an517-41/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21316'},
#  {'title': 'ACER Nitro KG272UBMIIPX, 27″ LED IPS WQHD',
#   'price': '16.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-kg272ubmiipx-27-led-ips-wqhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21758'},
#  {'title': 'Acer Nitro N50-640',
#   'price': '64.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/21720/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21720'},
#  {'title': 'ACER NITRO N50-640',
#   'price': '82.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-n50-640/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21726'},
#  {'title': 'ACER Nitro VG240YBMIIX, 24″ LED IPS FHD',
#   'price': '10.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-vg240ybmiix-24-led-ips-fhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21764'},
#  {'title': 'ACER Nitro VG270BMIIX, 27″ LED IPS FHD',
#   'price': '12.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-vg270bmiix-27-led-ips-fhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21771'},
#  {'title': 'Acer Predator Helios 300 PH315-54',
#   'price': '67.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/predator-helios-300-ph315-54/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21392'},
#  {'title': 'ACER Predator Helios 300 PH315-54-732Y',
#   'price': '103.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-732y/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21403'},
#  {'title': 'Acer Predator Helios 300 PH315-54-75YK',
#   'price': '83.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-75yk/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21401'},
#  {'title': 'Acer Predator Helios 300 PH315-54-945Y',
#   'price': '96.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-945y/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21398'},
#  {'title': 'Acer Predator Helios 300 PH315-54-949Y',
#   'price': '89.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-949y/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21396'},
#  {'title': 'ACER Predator Helios 300 PH317-55-962G',
#   'price': '114.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-helios-300-ph317-55-962g/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21412'},
#  {'title': 'Acer Swift 3 SF314-43',
#   'price': '31.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-swift-3-sf314-43/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21528'},
#  {'title': 'Acer Swift 3 SF314-43',
#   'price': '34.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-swift-3-sf314-43-2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21536'},
#  {'title': 'ACER Swift 3 SF314-511-56XT ( Silver )',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-sf314-43-r2f9-nx-ab1ex-003/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=20829'},
#  {'title': 'Acer Swift 3 SF314-511-56XT, Silver',
#   'price': '39.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-swift-3-sf314-511-56xt-silver/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21702'},
#  {'title': 'Apple iPad 2020 32GB WiFi Space Gray',
#   'price': '27.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-ipad-2020-32gb-wifi-space-gray/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=17828'},
#  {'title': 'Apple iPad Air (2020) 64GB 4GB RAM',
#   'price': '39.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-ipad-air-2020-64gb-4gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=18811'},
#  {'title': 'Apple iPad Air 2020 WIFI only 256GB blue',
#   'price': '51.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-ipad-air-2020-wifi-only-256gb-blue/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=17834'},
#  {'title': 'Apple iPad Pro 11 (2021) 128GB 8GB RAM',
#   'price': '63.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-ipad-pro-11-2021-128gb-8gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=21013'},
#  {'title': 'Apple iPad Pro 12.9 (2021) 128GB 8GB RAM',
#   'price': '91.000 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-ipad-pro-12-9-2021-128gb-8gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=18701'},
#  {'title': 'Apple iPhone 11 128GB 4GB RAM',
#   'price': '42.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-11-128gb-4gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=18937'},
#  {'title': 'Apple iPhone 11 64GB 4GB RAM',
#   'price': '38.990 ден',
#   'discounted_price': '31.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-11/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/2/?add-to-cart=18562'},
#  {'title': 'Apple iPhone 12 128GB 4GB RAM',
#   'price': '49.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-12-128gb-4gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20023'},
#  {'title': 'Apple iPhone 12 64GB 4GB RAM',
#   'price': '39.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-12/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18640'},
#  {'title': 'Apple iPhone 12 mini 128GB 4GB RAM',
#   'price': '39.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-12-mini-128gb-4gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20449'},
#  {'title': 'Apple iPhone 13 128GB 4GB RAM',
#   'price': '53.990 ден',
#   'discounted_price': '47.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18520'},
#  {'title': 'Apple iPhone 13 256GB 4GB RAM',
#   'price': '60.190 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-256gb-4gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20019'},
#  {'title': 'Apple iPhone 13 mini 128GB 4GB',
#   'price': '48.990 ден',
#   'discounted_price': '45.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-mini/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18661'},
#  {'title': 'Apple iPhone 13 Pro 128GB 6GB RAM',
#   'price': '66.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-pro/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18526'},
#  {'title': 'Apple iPhone 13 Pro 256GB 6GB RAM',
#   'price': '78.090 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-pro-256gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20015'},
#  {'title': 'Apple iPhone 13 Pro Max 128GB 6GB RAM',
#   'price': '75.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-pro-max/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18555'},
#  {'title': 'Apple iPhone 13 Pro Max 256GB 6GB RAM',
#   'price': '84.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-13-pro-max-256gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18924'},
#  {'title': 'Apple iPhone 14 128GB 6GB RAM',
#   'price': '59.990 ден',
#   'discounted_price': '54.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-14-128gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=22870'},
#  {'title': 'Apple iPhone 14 Plus 128GB 6GB RAM',
#   'price': '59.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-14-plus-128gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=22878'},
#  {'title': 'Apple iPhone 14 Pro 128GB 6GB RAM',
#   'price': '89.990 ден',
#   'discounted_price': '79.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-14-pro-128gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=22884'},
#  {'title': 'Apple iPhone 14 Pro Max 128GB 6GB RAM',
#   'price': '89.990 ден',
#   'discounted_price': '84.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-14-pro-max-128gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=22891'},
#  {'title': 'Apple iPhone 14 Pro Max 256GB 6GB RAM',
#   'price': '105.000 ден',
#   'discounted_price': '96.990 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-14-pro-max-256gb-6gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=23600'},
#  {'title': 'Apple iPhone SE 128GB 3GB RAM',
#   'price': '29.690 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-se-2020-128gb-3gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18691'},
#  {'title': 'Apple iPhone SE 64GB 3GB RAM',
#   'price': '32.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-iphone-se-2020-64gb-3gb-ram/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=18945'},
#  {'title': 'Apple Watch Series 7',
#   'price': '28.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/apple-watch-series-7/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=19657'},
#  {'title': 'Asus E410MA',
#   'price': '10.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-e410ma/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=22702'},
#  {'title': 'ASUS ROG GL531GT-XS53',
#   'price': '44.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-rog-gl531gt-xs53/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20931'},
#  {'title': 'Asus ROG Strix G15 Advantage Edition G513',
#   'price': '112.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-rog-strix-g15-advantage-edition-g513/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=21336'},
#  {'title': 'Asus TUF Gaming F15 FX506LH',
#   'price': '39.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-tuf-gaming-f15-fx506lh/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=21950'},
#  {'title': 'ASUS TUF Gaming F17 FX706HEB',
#   'price': '59.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-tuf-gaming-f17-fx706heb/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=20967'},
#  {'title': 'ASUS TUF Gaming NVIDIA GeForce RTX 3070 V2 OC Edition Video Card',
#   'price': '75.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/asus-tuf-gaming-nvidia-geforce-rtx-3070-v2-oc-edition-video-card/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/3/?add-to-cart=17873'},
#  {'title': 'DELL 23,8″ P2421D IPS LED-backlit LCD monitor',
#   'price': '16.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-238-p2421d-ips-led-backlit-lcd-monitor/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17338'},
#  {'title': 'DELL AW2521HFLA 24.5″ FHD',
#   'price': '20.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-aw2521hfla-24-5-fhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17415'},
#  {'title': 'DELL AW2721D 27″ QHD 2560 x 1440',
#   'price': '39.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-aw2721d-27-qhd-2560-x-1440/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17422'},
#  {'title': 'DELL Curved S2422HG 23.6″ VA LED-backlit LCD',
#   'price': '16.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-curved-s2422hg-23-6-va-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17393'},
#  {'title': 'Dell G15 5511 Gaming Laptop',
#   'price': '104.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-g15-5511-gaming-laptop/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=21340'},
#  {'title': 'DELL Monitor E2222HS  21.5″ VA',
#   'price': '9.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-e2222hs-21-5-va/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17118'},
#  {'title': 'DELL Monitor E2420HS, 23.8″ IPS Led AG',
#   'price': '11.690 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-e2420hs-23-8-ips-led-ag/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17253'},
#  {'title': 'DELL Monitor E2720H, 27.0″',
#   'price': '11.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-e2720h-27-0/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17271'},
#  {'title': 'DELL Monitor E2720HS 27.0″',
#   'price': '12.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-e2720hs-27-0-ips-led-ag/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17260'},
#  {'title': 'DELL Monitor P2222H, 22” Full HD',
#   'price': '12.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-p2222h-22-full-hd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17317'},
#  {'title': 'DELL Monitor S2721HS, 27″, IPS LED-backlit LCD',
#   'price': '14.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-s2721hs-27-ips-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17291'},
#  {'title': 'DELL Monitor SE2422H 23.8″',
#   'price': '8.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-se2422h-23-8/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17277'},
#  {'title': 'DELL Monitor SE2722H, 27″ VA LED-backlit LCD',
#   'price': '10.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-se2722h-27-va-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17283'},
#  {'title': 'DELL Monitor Video Conferencing S2422HZ, 24″ IPS LED-backlit LCD',
#   'price': '20.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2422hz-24-ips-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17301'},
#  {'title': 'DELL Monitor Video Conferencing S2722DZ, 27″ IPS WLED-backlit LCD',
#   'price': '27.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2722dz-27-ips-wled-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17310'},
#  {'title': 'DELL NB Latitude 5420,11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro),14.0″ FHD(1920×1080)AG 250nits,16GB DDR4 non-ECC Memory,512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4,Wi-Fi6,BT5.1,Bckl Kb,4Cell,Win10Pro,3Y',
#   'price': '71.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-542011th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro14-0-fhd1920x1080ag-250nits16gb-ddr4-non-ecc-memory512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graph/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23124'},
#  {'title': 'DELL NB Latitude 5420,11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro),14.0″ FHD(1920×1080)AG 250nits,16GB DDR4 non-ECC Memory,512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4,Wireless,BT5.1,Bkl Kb,FP,4Cell,Ubuntu,3Y',
#   'price': '62.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-542011th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro14-0-fhd1920x1080ag-250nits16gb-ddr4-non-ecc-memory512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graph-2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23132'},
#  {'title': 'DELL NB Latitude 5430, 12th Gen. Intel i7-1255U(10C/12T/12MB/1.7GHz to 4.7GHz), 14″ FHD(1920×1080)AG WVA 250nits, 16GB(1x16GB) DDR4 3200MHz, 512 M.2 PCIe NVMe SSD, Intel Iris Xe Graphics, AX211 WiFi6e 2×2 AX+BT 5.2, SCR, TB4, 4cell 58WHr, Ubuntu, 3Y',
#   'price': '72.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5430-12th-gen-intel-i7-1255u10c-12t-12mb-1-7ghz-to-4-7ghz-14-fhd1920x1080ag-wva-250nits-16gb1x16gb-ddr4-3200mhz-512-m-2-pcie-nvme-ssd-intel-iris-xe-graphics-ax211-wifi6/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23091'},
#  {'title': 'DELL NB Latitude 5431, 12th Gen.Intel Core i7-1270P vPro(12C/16T/18MB/up to 4.8GHz), 14″ FHD (1920×1080) IPS AG 250nits, 16GB (1X16GB) DDR5 4800MHz, 512GB M.2 PCIe NVMe SSD, Intel Iris Xe Graphics,WiFi6e+BT5.2,FPR,SCR,Bckl kb,4Cell 64WHr,Win11Pro,3Y',
#   'price': '87.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5431-12th-gen-intel-core-i7-1270p-vpro12c-16t-18mb-up-to-4-8ghz-14-fhd-1920x1080-ips-ag-250nits-16gb-1x16gb-ddr5-4800mhz-512gb-m-2-pcie-nvme-ssd-intel-iris-xe-graphicswi/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23080'},
#  {'title': 'DELL NB Latitude 5520, 11th.Gen.Intel Core i5-1135G7(4 Core,8M cache,2.4GHz to 4.2GHz), 15.6″ FHD(1920×1080)AG 250nits, 8GB (1X8GB) DDR4 non-ECC, 256GB M.2 PCIe NVMe Class 35 SSD, Intel Iris Xe Graphics,TB4,SCR,Wireless,BT5.1,Bkl Kb,4Cell,Ubuntu,3Y',
#   'price': '58.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-gen-intel-core-i5-1135g74-core8m-cache2-4ghz-to-4-2ghz-15-6-fhd1920x1080ag-250nits-8gb-1x8gb-ddr4-non-ecc-256gb-m-2-pcie-nvme-class-35-ssd-intel-iris-xe-graph/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23116'},
#  {'title': 'DELL NB Latitude 5520, 11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro), 15.6″ FHD(1920×1080)AG 250nits, 16GB DDR4 non-ECC, 512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4,FP,SCR,Wireless,BT5.1,Bckl Kb,4Cell,Ubuntu,3Y',
#   'price': '63.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro-15-6-fhd1920x1080ag-250nits-16gb-ddr4-non-ecc-512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graphics-2/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23107'},
#  {'title': 'DELL NB Latitude 5520, 11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro), 15.6″ FHD(1920×1080)AG 250nits, 16GB DDR4 non-ECC, 512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4,SCR,Wireless,BT5.1,Bckl Kb,4Cell,Win10Pro,3Y',
#   'price': '71.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro-15-6-fhd1920x1080ag-250nits-16gb-ddr4-non-ecc-512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graphics/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23099'},
#  {'title': 'DELL NB Latitude 5531, 12th Gen. Intel Core i7-12800H vPro(14C/20T/24MB/up to 4.8GHz), 15.6″ FHD (1920×1080) IPS AG 250nits, 32GB (1X32GB) DDR5 4800MHz, 512GB M.2 PCIe NVMe SSD, Intel Iris Xe Graphics, WiFi6e+BT5.2, Bckl kb, 4Cell 64WHr, Win11Pro, 3Y',
#   'price': '101.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5531-12th-gen-intel-core-i7-12800h-vpro14c-20t-24mb-up-to-4-8ghz-15-6-fhd-1920x1080-ips-ag-250nits-32gb-1x32gb-ddr5-4800mhz-512gb-m-2-pcie-nvme-ssd-intel-iris-xe-graphic/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=23069'},
#  {'title': 'DELL P2422H 23.8″ IPS WLED-backlit LCD',
#   'price': '13.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-p2422h-23-8-ips-wled-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/4/?add-to-cart=17325'},
#  {'title': 'DELL P2422HE 23.8″ IPS WLED-backlit LCD',
#   'price': '16.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-p2422he-23-8-ips-wled-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17331'},
#  {'title': 'DELL P2720D 27″ IPS WLED-backlit LCD monitor',
#   'price': '18.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-p2720d-27-ips-wled-backlit-lcd-monitor/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17353'},
#  {'title': 'DELL P2722H 27″ IPS WLED-backlit LCD monitor AG',
#   'price': '15.999 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-p2722h-27-ips-wled-backlit-lcd-monitor-ag/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17347'},
#  {'title': 'Dell PC Optiplex 3050 MT, Intel Core i3-7100',
#   'price': '37.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-pc-optiplex-3050-mt-intel-core-i3-7100/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17438'},
#  {'title': 'Dell PC OptiPlex 3080 SFF, Intel Core i5-10505',
#   'price': '40.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-pc-optiplex-3080-sff-intel-core-i5-10505/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17444'},
#  {'title': 'DELL PC OptiPlex 3090 SFF, Intel Core i5-10505',
#   'price': '41.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-pc-optiplex-3090-sff-intel-core-i5-10505-6-cores-12mb-12t-3-2ghz-to-4-6ghz-65w-8gb1x8gb-ddr4-256gb-m-2-pcie-nvme-class-35-ssd-intel-integrated-graphics-dvd-rw-dp-hdmi-2-0-ms116-mous/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=23140'},
#  {'title': 'DELL S2421HGF 23,8″ TN LED-backlit LCD',
#   'price': '14.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-s2421hgf-238-tn-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17386'},
#  {'title': 'DELL S2522HG 24.5″ Fast IPS LED-backlit LCD',
#   'price': '18.690 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-s2522hg-24-5-fast-ips-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17400'},
#  {'title': 'DELL S2721HGF 27″ VA LED-backlit LCD',
#   'price': '17.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-s2721hgf-27-va-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17407'},
#  {'title': 'DELL U2421E 24,1″ IPS LED-backlit LCD',
#   'price': '20.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-u2421e-241-ips-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17358'},
#  {'title': 'DELL U2422H 23.8″ IPS WLED-backlit LCD',
#   'price': '16.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-u2422h-23-8-ips-wled-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17366'},
#  {'title': 'DELL U2722D 27″ IPS LED-backlit LCD',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-u2722d-27-ips-led-backlit-lcd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=17373'},
#  {'title': 'DELL Vostro 3510',
#   'price': '43.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-vostro-3510/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=21084'},
#  {'title': 'Epson L1110 Inkjet w/ Eco Tank System (CISS)',
#   'price': '8.190 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l1110-inkjet-w-eco-tank-system-ciss/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19879'},
#  {'title': 'Epson L1300 InkJet A3+ CISS System',
#   'price': '32.350 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l1300-inkjet-a3-ciss-system/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19983'},
#  {'title': 'Epson L14150 Inkjet A3+ MFP LAN/WiFI w/ EcoTank System (CISS)',
#   'price': '32.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l14150-inkjet-a3-mfp-lan-wifi-w-ecotank-system-ciss/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19991'},
#  {'title': 'Epson L15160 MFP A3+ EcoTank System',
#   'price': '67.190 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l15160-mfp-a3-ecotank-system/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19999'},
#  {'title': 'Epson L1800 A3+ Photo CISS System',
#   'price': '37.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l1800-a3-photo-ciss-system/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19996'},
#  {'title': 'Epson L3211 Inkjet w/ Eco Tank System (CISS) MFP Printer',
#   'price': '11.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l3211-inkjet-w-eco-tank-system-ciss-mfp-printer/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19882'},
#  {'title': 'Epson L3251 Inkjet w/ Eco Tank System (CISS) MFP WiFi Direct',
#   'price': '12.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l3251-inkjet-w-eco-tank-system-ciss-mfp-wifi-direct/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19885'},
#  {'title': 'Epson L5290 Inkjet w/ INK Tank System (CISS) MFP Fax/WiFi/LAN',
#   'price': '17.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l5290-inkjet-w-ink-tank-system-ciss-mfp-fax-wifi-lan/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19888'},
#  {'title': 'EPSON L805 Inkjet Photo w/ Ink Tank System (CISS)',
#   'price': '20.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-l805-inkjet-photo-w-ink-tank-system-ciss/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19628'},
#  {'title': 'EPSON LQ-350+ kirilica',
#   'price': '19.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-lq-350-kirilica/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19894'},
#  {'title': 'EPSON LX-350+ kirilica',
#   'price': '18.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/epson-lx-350-kirilica/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/5/?add-to-cart=19891'},
#  {'title': 'EVGA GeForce GT 1030 SC 2GB 64-Bit GDDR5',
#   'price': '10.990 ден',
#   'discounted_price': '9.990 ден',
#   'link': 'https://clevershop.mk/product/evga-geforce-gt-1030-sc-2gb-64-bit-gddr5/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=17841'},
#  {'title': 'Evolve III Maestro E-Book 11.6″',
#   'price': '7.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/evolve-iii-maestro-e-book-11-6/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=20308'},
#  {'title': 'Gateway GWNC31514',
#   'price': '19.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/gateway-gwnc31514/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21184'},
#  {'title': 'Gateway GWTN156-11BK',
#   'price': '12.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/gateway-gwtn156-11bk/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=22713'},
#  {'title': 'Gigabyte GeForce RTX 3090 Turbo GDDR6X Graphics Card *High Hash Rate',
#   'price': '199.900 ден',
#   'discounted_price': '189.990 ден',
#   'link': 'https://clevershop.mk/product/gigabyte-geforce-rtx-3090-turbo-gddr6x-graphics-card-high-hash-rate/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=17896'},
#  {'title': 'GIGABYTE GeForce RTX™ 3080 GAMING OC 10G (rev. 2.0)',
#   'price': '117.900 ден',
#   'discounted_price': '109.990 ден',
#   'link': 'https://clevershop.mk/product/geforce-rtx-3080-gaming-oc-10g-rev-2-0/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=17886'},
#  {'title': 'Google Pixel 6 128GB 8GB RAM',
#   'price': '47.990 ден',
#   'discounted_price': '43.990 ден',
#   'link': 'https://clevershop.mk/product/google-pixel-6/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=18625'},
#  {'title': 'Google Pixel 6 Pro 256GB 12GB',
#   'price': '69.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/google-pixel-6-pro-256gb-12gb/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=18630'},
#  {'title': 'HP 14-DQ0031',
#   'price': '12.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-14-dq0031/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=20957'},
#  {'title': 'HP 15-DW3138NIA',
#   'price': '28.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-15-dw3138nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21579'},
#  {'title': 'HP 15-dw3142nia',
#   'price': '40.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-15-dw3142nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21585'},
#  {'title': 'HP 15s-eq2382nia',
#   'price': '32.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-15s-eq2382nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21582'},
#  {'title': 'HP 250 G8 2X7T8EA',
#   'price': '18.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-250-g8-2x7t8ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=18333'},
#  {'title': 'HP 250 G8, 2W8Z6EA',
#   'price': '22.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-250-g8-2w8z6ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21557'},
#  {'title': 'HP 250 G8, 2X7W8EA',
#   'price': '16.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-250-g8-2x7w8ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21548'},
#  {'title': 'HP 255 G8, 27K51EA',
#   'price': '22.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-255-g8-27k51ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=18512'},
#  {'title': 'HP 255 G8, 3V5K4EA',
#   'price': '24.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-255-g8-3v5k4ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21565'},
#  {'title': 'HP Color Laser 150a',
#   'price': '10.580 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-printer-color-laser-150a/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=17631'},
#  {'title': 'HP ENVY 13-BA1053NN',
#   'price': '55.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-envy-13-ba1053nn/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21591'},
#  {'title': 'HP ENVY X360 13-AY1007NN',
#   'price': '59.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-envy-x360-13-ay1007nn/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21598'},
#  {'title': 'HP Laptop 14-dq0001dx',
#   'price': '13.990 ден',
#   'discounted_price': '12.490 ден',
#   'link': 'https://clevershop.mk/product/hp-laptop-14-dq0001dx/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21192'},
#  {'title': 'HP LAPTOP 15S-FQ2002NIA',
#   'price': '31.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-laptop-15s-fq2002nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21572'},
#  {'title': 'HP LAPTOP 15S-FQ2003NIA',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-laptop-15s-fq2003nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=21575'},
#  {'title': 'HP Laptop 15s-fq3000na',
#   'price': '21.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-laptop-15s-fq3000na/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/6/?add-to-cart=18348'},
#  {'title': 'HP Laptop 15s-fq3001na',
#   'price': '17.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/18341/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=18341'},
#  {'title': 'HP LaserJet Pro M404dn',
#   'price': '15.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-printer-laserjet-pro-m404dn/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=17628'},
#  {'title': 'HP LaserJet Pro MFP M428fdw',
#   'price': '28.790 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-printer-mfp-laserjet-pro-m428fdw/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=17734'},
#  {'title': 'HP MLJ M236dw, 9YF95A мултифункциски ласерски принтер',
#   'price': '11.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-mlj-m236dw-9yf95a-%d0%bc%d1%83%d0%bb%d1%82%d0%b8%d1%84%d1%83%d0%bd%d0%ba%d1%86%d0%b8%d1%81%d0%ba%d0%b8-%d0%bb%d0%b0%d1%81%d0%b5%d1%80%d1%81%d0%ba%d0%b8-%d0%bf%d1%80%d0%b8%d0%bd%d1%82%d0%b5%d1%80/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=23298'},
#  {'title': 'HP P24 G4 23.8″ Full HD LCD Monitor',
#   'price': '8.190 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-p24-g4-23-8-full-hd-lcd-monitor/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=21713'},
#  {'title': 'HP Pav Gaming Desktop TG01',
#   'price': '44.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-pav-gaming-desktop-tg01/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=21785'},
#  {'title': 'HP PAV X360 14-DY1000NA',
#   'price': '60.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/21594/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=21594'},
#  {'title': 'HP PAV X360 14-DY1005NA',
#   'price': '46.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-pav-x360-14-dy1005na/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=21588'},
#  {'title': 'HP Pavilion Gaming Laptop 15-dk2111nia',
#   'price': '74.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-pavilion-gaming-laptop-15-dk2111nia/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/7/?add-to-cart=21377'},
#  {'title': 'HP Printer Color LaserJet Pro MFP M283fdw',
#   'price': '27.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-printer-color-laserjet-pro-mfp-m283fdw/',
# ...
#   'price': '14.858 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/aoc-cq27g2u-bk-27-va-144hz-2560x1440/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=12260'},
#  {'title': 'Bakeey Z19 SMART часовник',
#   'price': '1.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/bakeey-z19-smart-%d1%87%d0%b0%d1%81%d0%be%d0%b2%d0%bd%d0%b8%d0%ba/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=11274'},
#  {'title': 'Acer Aspire 3 A317-33, NX.A6TEX.00A',
#   'price': '26.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-205-g4-22-all-in-one-pc-9ug19ea/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=17221'},
#  {'title': 'Acer Chromebook 11 CB311-9H-C4XC NX.HKFAA.007',
#   'price': '11.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-chromebook-11-cb311-9h-c4xc-nx-hkfaa-007/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=13124'},
#  {'title': 'Acer Nitro 5 AN515-55 NH.Q7MEX.00R',
#   'price': '47.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-5-an515-55-nh-q7mex-00r/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=17235'},
#  {'title': 'Acer Predator Triton 500 SE PT516-51s',
#   'price': '107.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-predator-triton-500-se-pt516-51s-intel-windows-10-home-intel-core-i7-11800h-24-ghz-core-8-16gb-16-wqxga-ips-ssdgb-512-m-2-pcie-nvme-nvidia-rtx-3070-8gb-802-11a-b-g-n-bluetooth-5/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=17241'},
#  {'title': 'ACER Swift 1 (SF114-33-P3EE), Silver',
#   'price': '25.990 ден',
#   'discounted_price': '21.990 ден',
#   'link': 'https://clevershop.mk/product/notebook-acer-swift-1-sf114-33-p3ee-silver-14-fhd-ips-intel-pentium-silver-processor-n5030-8gb-ddr4-256gb-nvme-ssd-4xusb-figerprint-camera-hdmi-bt-linux/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=16939'},
#  {'title': 'ACER Swift 1 (SF114-33-P629), Gold',
#   'price': '27.990 ден',
#   'discounted_price': '21.990 ден',
#   'link': 'https://clevershop.mk/product/acer-swift-1-sf114-33-p629-gold-14-fhd-ips-intel-pentium-silver-processor-n5030-8gb-ddr4-256gb-nvme-ssd-4xusb-figerprint-camera-hdmi-bt-linux/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=16946'},
#  {'title': 'ACER SWiIFT 3, SF314-511-56XT, Silver, 14” FHD, Intel® Core™ i5-1135G7, 16G DDR4, 512GB SSD, 1xUSB Type-C / Thunderbolt™ 4, 1xUSB 3.2, Figerprint, Camera, HDMI,  BT, Linux',
#   'price': '44.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-swiift-3-sf314-511-56xt-silver-14-fhd-intel-core-i5-1135g7-16g-ddr4-512gb-ssd-1xusb-type-c-thunderbolt-4-1xusb-3-2-figerprint-camera-hdmi-bt-linux/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/12/?add-to-cart=16978'},
#  {'title': 'Asus VivoBook X413JA-211.VBWB',
#   'price': '25.990 ден',
#   'discounted_price': '19.990 ден',
#   'link': 'https://clevershop.mk/product/asus-vivobook-x413ja-211-vbwb/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12999'},
#  {'title': 'DELL NB Latitude 5520, 11th Intel Core i5-1135G7 (4C/8T/8MB/2.4GHz), 15.6″ FHD (1920×1080) 250nits, 8GB DDR4, M.2 256GB PCIe NVMe, FPR Reader, SmartCard Reader, TB4, Cam+Mic, 4Cell 63WHr, 65W Type-C, AX201+BT5.1, WLAN/WWAN, Backlit kbd, Win10Pro, 3Y',
#   'price': '62.690 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-intel-core-i5-1135g7-4c-8t-8mb-2-4ghz-15-6-fhd-1920x1080-250nits-8gb-ddr4-m-2-256gb-pcie-nvme-fpr-reader-smartcard-reader-tb4-cammic-4cell-63whr-65w-type-c/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17156'},
#  {'title': 'DELL NB Vostro 3515, AMD Ryzen™ 3 3250U (2 Core,4M cache,2.6GHz to 3.5GHz), 15.6″ FHD(1920×1080) WVA AG 220 nits, 8GB(1x8GB) DDR4, 256GB M.2 PCIe NVMe SSD, Integrated graphics with AMD APU, Wi-Fi, BT5.0, Bckl Kb, 3-Cell, Ubuntu 20.04, Carbon Black,3Y',
#   'price': '27.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-vostro-3515-amd-ryzen-3-3250u-2-core4m-cache2-6ghz-to-3-5ghz-15-6-fhd1920x1080-wva-ag-220-nits-8gb1x8gb-ddr4-256gb-m-2-pcie-nvme-ssd-integrated-graphics-with-amd-apu-w/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17066'},
#  {'title': 'DELL NB Vostro 3515, AMD Ryzen™ 5 3450U (4 Core,4M cache,2.1GHz to 3.5GHz), 15.6″ FHD (1920×1080) WVA AG 220 nits, 8GB (1x8GB) DDR4, 512GB M.2 PCIe NVMe SSD, AMD Radeon Vega 8 Graphics, Wi-Fi, BT, 3cell 41WHr, Ubuntu 20.04, Carbon Black, 3Y',
#   'price': '33.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/dell-nb-vostro-3515-amd-ryzen-5-3450u-4-core4m-cache2-1ghz-to-3-5ghz-15-6-fhd-1920x1080-wva-ag-220-nits-8gb-1x8gb-ddr4-512gb-m-2-pcie-nvme-ssd-amd-radeon-vega-8-graphics-wi-fi/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17071'},
#  {'title': 'HP Chromebook 11A-NB0013 11.6″ 4GB 32GB Intel Celeron N3350 X2 1.1GHz Chrome OS, Ash Gray',
#   'price': '11.990 ден',
#   'discounted_price': '10.990 ден',
#   'link': 'https://clevershop.mk/product/hp-chromebook-11a-nb0013-11-6-4gb-32gb-intel-celeron-n3350-x2-1-1ghz-chrome-os-ash-gray/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=16676'},
#  {'title': 'HP NB OMEN 15-en0011nia, Ryzen 5-4600H hexa, 15.6” FHD Antiglare ultraslim IPS 144Hz Narrow Border, 8GB DDR4 2DM 3200, 512GB PCIe SSD, Nvidia GeForce 1650Ti 4GB, Win10 Home, Mica Silver, 3Y',
#   'price': '65.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-nb-omen-15-en0011nia-ryzen-5-4600h-hexa-15-6-fhd-antiglare-ultraslim-ips-144hz-narrow-border-8gb-ddr4-2dm-3200-512gb-pcie-ssd-nvidia-geforce-1650ti-4gb-win10-home-mica-silver-3y/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17202'},
#  {'title': 'Tablet PC, Veidoo 10 Inch Android Tablet, 10.1 inch IPS Screen, Dual Camera, WiFi/GPS/OTG/Bluetooth, 3G Phone Call Dual SIM Card Slots, 2GB RAM, 32GB Storage, 5000mAh Battery',
#   'price': '5.990 ден',
#   'discounted_price': '5.290 ден',
#   'link': 'https://clevershop.mk/product/tablet-pc-veidoo-10-inch-android-tablet-10-1-inch-ips-screen-dual-camera-wifi-gps-otg-bluetooth-3g-phone-call-dual-sim-card-slots-2gb-ram-32gb-storage-5000mah-battery/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=13085'},
#  {'title': 'FS200 Mini Portable SSD – USB3.1',
#   'price': '999 ден',
#   'discounted_price': '2.490 ден',
#   'link': 'https://clevershop.mk/product/fs200-mini-portable-ssd-usb3-1/',
#   'add_to_cart': None},
#  {'title': 'G2590FX 24.5″ TN 144Hz 1920 x 1080',
#   'price': '11.490 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/g2590fx-24-5-tn-1920-x-1080-144hz/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12166'},
#  {'title': 'HP 27″ 3WL54AA QHD 144 Hz 2560 x 1440',
#   'price': '21.090 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-27%e2%80%b3-3wl54aa-qhd-144-hz-2560-x-1440/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12311'},
#  {'title': 'HP OMEN X gaming display 25″, 4WH47AA',
#   'price': '17.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-omen-x-gaming-display-25-4wh47aa/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12413'},
#  {'title': 'Lemfo LEM1995 SMART женска бразлетна',
#   'price': '1.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/lemfo-lem1995-smart-%d0%b6%d0%b5%d0%bd%d1%81%d0%ba%d0%b0-%d0%b1%d1%80%d0%b0%d0%b7%d0%bb%d0%b5%d1%82%d0%bd%d0%b0/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=11279'},
#  {'title': 'LG 27” QHD Ergo IPS Monitor with USB Type-C™',
#   'price': '23.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/lg-27-qhd-ergo-ips-monitor-with-usb-type-c/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12561'},
#  {'title': 'MON 15.6 AOC I1601FWUX',
#   'price': '10.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12599'},
#  {'title': 'MON 24 ASUS VG249Q FHD IPS Gaming 144Hz HDMI DP FreeSync',
#   'price': '14.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-24-asus-vg249q-fhd-ips-gaming-144hz-hdmi-dp-freesync/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12590'},
#  {'title': 'Acer ED270R 27″ Black 1920 x 1080 Widescreen 16:9 165Hz Refresh Rate AMD FreeSync Premium Technology, 2x HDMI, DisplayPort Curved LED Gaming Monitor',
#   'price': '14.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-ed270r-27-black-1920-x-1080-widescreen-169-165hz-refresh-rate-amd-freesync-premium-technology-2x-hdmi-displayport-curved-led-gaming-monitor/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17058'},
#  {'title': 'Acer ED323QUR Abidpx 31.5 Inches WQHD (2560 x 1440) Curved 1800R VA Gaming Monitor with AMD Radeon FREESYNC Technology – 4ms; 144Hz Refresh Rate; Display Port, HDMI Port & DVI Port, Black',
#   'price': '21.290 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-ed323qur-abidpx-31-5-inches-wqhd-2560-x-1440-curved-1800r-va-gaming-monitor-with-amd-radeon-freesync-technology-4ms-144hz-refresh-rate-display-port-hdmi-port-dvi-port-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17043'},
#  {'title': 'Acer Nitro VG271U Pbmiipx 27″ WQHD (2560 x 1440) IPS AMD Radeon FREESYNC Gaming Monitor, 144Hz, VESA Certified Display HDR400, DCI-P3, (2 x HDMI 2.0 Ports & 1 x Display Port), Black',
#   'price': '19.790 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-vg271u-pbmiipx-27-wqhd-2560-x-1440-ips-amd-radeon-freesync-gaming-monitor-144hz-vesa-certified-display-hdr400-dci-p3-2-x-hdmi-2-0-ports-1-x-display-port-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17035'},
#  {'title': 'ACER Nitro VG272SBMIIPX, 27″ LED IPS FHD, 165Hz, min 0,5ms (GtoG) 2x2W speakers Black',
#   'price': '14.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-vg272sbmiipx-27-led-ips-fhd-165hz-min-05ms-gtog-2x2w-speakers-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17003'},
#  {'title': 'ACER Nitro XV240Y Pbmiiprx 23.8″ LED IPS FHD, 165Hz, min 0,1ms (GtoG), 1000:1, 250nits',
#   'price': '12.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-xv240y-pbmiiprx-23-8-led-ips-fhd-165hz-min-01ms-gtog-10001-250nits/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17051'},
#  {'title': 'ACER Nitro XV252QZBMIIPRX 24.5″ LED IPS FHD, up to 280Hz, min 0,5ms (GtoG) 1000:1 400nits HDMI DP Height adj. Pivot  Black',
#   'price': '18.790 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-nitro-xv252qzbmiiprx-24-5-led-ips-fhd-up-to-280hz-min-05ms-gtog-10001-400nits-hdmi-dp-height-adj-pivot-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17011'},
#  {'title': 'ACER R270SI  27” LED IPS FHD, ZeroFrame, 1ms VRB, Flicker-less,1000:1, 250nits, HDMI, Black',
#   'price': '9.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-r270si-27-led-ips-fhd-zeroframe-1ms-vrb-flicker-less10001-250nits-hdmi-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17019'},
#  {'title': 'ACER V277BIP 27” LED IPS FHD, ZeroFrame, 4ms, Flicker-less,1000:1, 250nits, HDMI, DP, Black',
#   'price': '9.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/acer-v277bip-27-led-ips-fhd-zeroframe-4ms-flicker-less10001-250nits-hdmi-dp-black/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=17026'},
#  {'title': 'MON 27 AOC AG273QCX',
#   'price': '27.190 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux-copy/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/13/?add-to-cart=12646'},
#  {'title': 'MON 27 LG 27GN850-B QHD IPS 1MS 144HZ HDMI',
#   'price': '29.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-27-lg-27gn850-b-qhd-ips-1ms-144hz-hdmi/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12543'},
#  {'title': 'MON 27 Philips 272B7QUPBEB/00 with USB-C Dock',
#   'price': '20.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-27-philips-272b7qupbeb-00-with-usb-c-dock/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12619'},
#  {'title': 'MON 27 Philips 272V8A/00',
#   'price': '10.590 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/mon-27-philips-272v8a-00/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12638'},
#  {'title': 'Monitor 27 Philips 272E1GAJ/00 VA 1ms 144Hz',
#   'price': '12.890 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/monitor-27-philips-272e1gaj-00-va-1ms-144hz/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12618'},
#  {'title': 'Philips 24″ 243V7QDSB',
#   'price': '8.390 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/philips-24%e2%80%b3-243v7qdsb/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12396'},
#  {'title': 'Philips 27″ 278E1A/00 4K UHD IPS',
#   'price': '18.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/hp-27%e2%80%b3-278e1a-00-4k-uhd-ips/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12218'},
#  {'title': 'Philips 279C9-00 MON LED 27″ 3840 x 2160 5Ms 60Hz 4K UHD',
#   'price': '26.990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/philips-279c9-00-mon-led-27-3840-x-2160-5ms-60hz-4k-uhd/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=12578'},
#  {'title': 'Xiaomi Redmi AirDots Wireless',
#   'price': '990 ден',
#   'discounted_price': '0 ден',
#   'link': 'https://clevershop.mk/product/redmi-headphones/',
#   'add_to_cart': 'https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/14/?add-to-cart=10663'}]

# %% [markdown]
# ### Create a pandas DataFrame with the scraped products

# %%
df = pd.DataFrame(products)
print(df.head())
# Out:
#                         title       price discounted_price  \
# 0           Acer A315-23-A7KD  17.590 ден            0 ден
# 1           Acer A315-23-R5P2  27.490 ден            0 ден
# 2       ACER Aspire 1 A115-22  18.999 ден       15.999 ден
# 3  Acer Aspire 3 A315-23-R26A  29.990 ден            0 ден
# 4  Acer Aspire 3 A315-58-33WK  24.490 ден            0 ден
#
#                                                 link  \
# 0   https://clevershop.mk/product/acer-a315-23-a7kd/
# 1   https://clevershop.mk/product/acer-a315-23-r5p2/
# 2  https://clevershop.mk/product/acer-aspire-1-nx...
# 3  https://clevershop.mk/product/acer-aspire-3-a3...
# 4               https://clevershop.mk/product/21498/
#
#                                          add_to_cart
# 0  https://clevershop.mk/product-category/mobilni...
# 1  https://clevershop.mk/product-category/mobilni...
# 2  https://clevershop.mk/product-category/mobilni...
# 3  https://clevershop.mk/product-category/mobilni...
# 4  https://clevershop.mk/product-category/mobilni...

# %% [markdown]
# Save the dataframe as `.csv`

# %%
df.to_csv("./products.csv", index=False)
